# %% [markdown]
# # Hi, this is a short tutorial for RISE

# %% [markdown]
# ## Housekeeping
#
# Deps for how I set up this notebook:
#   1. install RISE for this pres mode `conda install -c conda-forge rise`
#   2. install altair for data viz `conda install -c conda-forge altair vega_datasets notebook vega`
#   3. install jupyter configurator to add RISE themes (among other things) `conda install -c conda-forge jupyter_nbextensions_configurator`
#   4. install html parsing library `pip install request-html`

# %%
# Try get html from pybay schedule page ONCE
# If a pickled version of it exists then use that
# Else unpickle the stored version and load into memory
from requests_html import HTMLSession

session = HTMLSession()
pybay_schedule = session.get('https://pybay.com/schedule/')

# %%
# Define talk categories
talk_cats = dict()
for cat in pybay_schedule.html.find(".sch-filter-list", first=True).find('li'):
    if not cat.attrs["data-filter"].strip():
        continue
    talk_cats[cat.text.strip()] = cat.attrs["data-filter"]

talk_cats
# Out:
# {'Python & Libraries': 'python',
#  'DevOps, Testing, & Automation': 'devops',
#  'People & Project Management': 'community',
#  'Scale & Performance': 'speed',
#  'ML, AI, & Data': 'ai',
#  'Web, IoT, & Hardware': 'web',
#  'Beginner-friendly': 'level-1'}

# %%
# Parse schedule for talk information

import collections
talk_details = collections.namedtuple("TalkDetails", ["time", "title", "speaker", "categories", "description"])
talks = list()

def get_categories(cat_text: str) -> list:
    """
    Ex1: (ML, AI, & Data)
    Ex2: (DevOps, Testing, & Automation,
Web, IoT, & Hardware)
    """
    cats = cat_text.split("\n")
    cats = [cat.replace("(", "").replace(")", "") for cat in cats]
    cats = [cat[:-1] if cat.endswith(",") else cat for cat in cats]
    return [talk_cats[cat] for cat in cats]

for day in pybay_schedule.html.find(".sch-day"):
    if day.find(".sch-day-title", first=True).text not in {"Aug. 17, 2019", "Aug. 18, 2019"}:
        continue
    a = day.find(".sch-timeslots", first=True)
    b = a.find(".sch-timeslot")
    for timeslot in day.find(".sch-timeslots", first=True).find(".sch-timeslot"):
        if "sch-timeslot-special" in timeslot.attrs["class"]:
            continue  # skip things like check-in, breakfast, lunch, etc.
        time = timeslot.find(".sch-timeslot-time", first=True).text
        for talk in timeslot.find(".sch-timeslot-slots", first=True).find(".sch-timeslot-slot"):
            details = talk.find(".sch-slot-inner", first=True)
            title = details.find("h4 > a", first=True).text
            speaker = details.find("p.sch-speaker", first=True).text
            try:
                categories = get_categories(details.find("p.sch-category > span.small", first=True).text)
            except AttributeError:
                categories = []
            try:
                description = talk.find("div.sch-description > p", first = True).text
            except AttributeError:
                description = ""
            talks.append(talk_details(time, title, speaker, categories, description))

talks[:3]
# Out:
# [TalkDetails(time='9:40 a.m.', title='As We May Program', speaker='Peter Norvig', categories=['ai'], description='Innovations in machine learning are changing our perception of what is possible to do with a computer. But how will machine learning change the way we program, the tools we use, and the mix of tasks done by expert programmers, novice programmers, and non-programmers? This talk examines some possible futures.'),
#  TalkDetails(time='10:15 a.m.', title="PEP 581 and PEP 588: Migrating CPython's Issue Tracker", speaker='Mariatta .', categories=['python'], description="In 2017, CPython codebase was moved to GitHub from Mercurial, an effort that took more than three years of planning and lots of volunteer coordination. The move proved to be successful and well-appreciated. New contributors face less barriers when contributing to Python. Core developers are benefiting from personal assistants in the form of GitHub bots and automations. Can the workflow be even better? In this talk, we'll look into other problems in CPython's workflow: the issue tracker itself."),
#  TalkDetails(time='11:05 a.m.', title="What's Coming in 3.8? Assignment Expressions & More!", speaker='Adam Forsyth', categories=['python'], description="Curious what's coming next for Python? Well, Python 3.8 is being released just a few short months. It already includes a number of new features such as assignment expressions, improved debugging, more string formatting features, and many smaller changes. Come learn about the big ones and some of the more interesting small ones too!")]

# %%
import pandas as pd

df = pd.DataFrame(data=talks)
df
# Out:
#           time                                              title  \
# 0    9:40 a.m.                                  As We May Program
# 1   10:15 a.m.  PEP 581 and PEP 588: Migrating CPython's Issue...
# 2   11:05 a.m.  What's Coming in 3.8? Assignment Expressions &...
# 3   11:05 a.m.  Unclogging a VFX Production Pipeline with Anal...
# 4   11:05 a.m.  Koalas: Easy Transition from pandas to Apache ...
# 5   11:05 a.m.        Migrating from REST to GraphQL under Django
# 6   11:45 a.m.                      Python Steering Council Panel
# 7   11:45 a.m.  Full Stack Web with Nothing but Python: How An...
# 8   11:45 a.m.  Pushing the limits of Python: ML infra at Netflix
# 9    1:30 p.m.  Real-Time Bidding Models in Computational Adve...
# 10   1:30 p.m.        Amazing things your ORM(s) can and can't do
# 11   1:30 p.m.                             Python + Terraform = ♥
# 12   1:30 p.m.    An Intro to Load Testing with Locust and Python
# 13   2:10 p.m.                          Boring Object Orientation
# 14   2:10 p.m.                      Dependency Injection, Quickly
# 15   2:10 p.m.            Perceiving Python Programming Paradigms
# 16   2:10 p.m.  Make the Most of It: Negotiation and Self-Advo...
# 17   2:50 p.m.                          Extending GDB with Python
# 18   2:50 p.m.        Building a Sustainable Python Package Index
# 19   2:50 p.m.                Python and R for Advanced Analytics
# 20   3:45 p.m.                   Be Ye Therefore Wise As Serpents
# 21   3:45 p.m.  CUDA in your Python: Parallel Programming on t...
# 22   3:45 p.m.         Understanding Python’s Debugging Internals
# 23   3:45 p.m.               Audio processing and ML using python
# 24   4:40 p.m.       CuPy: A NumPy-compatible Library for the GPU
# 25   4:40 p.m.  Identifying influencers via Slack Messages in ...
# 26   4:40 p.m.  Plugins: using importlib to build self describ...
# 27   4:40 p.m.                        How to Write Pytest Plugins
# 28   5:20 p.m.                                    Lightning Talks
# 29   5:20 p.m.  Accelerating Driver Development with CircuitPy...
# 30   5:20 p.m.      (Deep) Learn You a Neural Net for Great Good!
# 31   9:15 a.m.                          The Mental Game of Python
# 32  10:40 a.m.  Airflow in Practice: Stop Worrying Start Lovin...
# 33  10:40 a.m.                                    EdgeDB & Python
# 34  10:40 a.m.      Effective Visual Representations using Python
# 35  10:40 a.m.       Customizing Sphinx: Simple, Normal, and Hard
# 36  11:20 a.m.  mypy - Getting to Four Million Lines of Typed ...
# 37  11:20 a.m.        My Path to Becoming a Python Core Developer
# 38  11:20 a.m.  Deploy Deep Learning models as Microservices i...
# 39  11:20 a.m.  Learning from Human Failures & Successes of Py...
# 40   1:05 p.m.                      Patterns for Clean API Design
# 41   1:05 p.m.  Building effective Django queries with express...
# 42   1:05 p.m.       Unit testing using monkey patching in pytest
# 43   1:45 p.m.            Getting Specific About Algorithmic Bias
# 44   1:45 p.m.               Understanding Concurrency in Python!
# 45   1:45 p.m.  Profiling Python/C++ ML applications using VSCode
# 46   1:45 p.m.  Generate, Extrude, Build: creating 3D objects ...
# 47   2:25 p.m.  The latest with BLACK, so you can stop worryin...
# 48   2:25 p.m.                 Browser security with HTTP headers
# 49   2:25 p.m.  Project Jupyter: Tools for Interactive, Reprod...
# 50   2:25 p.m.              Writing good python APIs with autosig
# 51   3:20 p.m.  Talking to data as you would with built-in types.
# 52   3:20 p.m.            Why you should be using structured logs
# 53   3:20 p.m.                            Data Access at Kiva.org
# 54      4 p.m.   Building contextual AI assistants with OSS tools
# 55      4 p.m.  Ask the Ecosystem: Lessons from 200+ FOSS Appl...
# 56      4 p.m.                                   Beyond Paradigms
# 57      4 p.m.                               AB testing in Python
#
#                                               speaker  \
# 0                                        Peter Norvig
# 1                                          Mariatta .
# 2                                        Adam Forsyth
# 3                                    Bridgette Powell
# 4                                             Xiao Li
# 5                                        Manish Sinha
# 6   Paul Everitt\nŁukasz Langa\nBarry Warsaw\nBenj...
# 7                                       Meredydd Luff
# 8    Ville Tuulos\nRavi Kiran Chirravuri\nSavin Goyal
# 9                                             Allie .
# 10                                   Louise Grandjonc
# 11                                     Wyatt Peterson
# 12                                     Gabriel Boorse
# 13                                        Moshe Zadka
# 14                                         Edwin Jung
# 15                                     Jigyasa Grover
# 16                                       Lusen Mendel
# 17                                         Lisa Roach
# 18                                      Dustin Ingram
# 19                                    Britton Stamper
# 20                                        Grant Jenks
# 21                                     William Horton
# 22                                   Liran Haimovitch
# 23                                      Jyotika Singh
# 24                                        Sean Farley
# 25                                         Eva Sasson
# 26                                     Daniel Wallace
# 27                                       Darlene Wong
# 28                                      Could be you!
# 29                                      Bryan Siepert
# 30                                        Stu Stewart
# 31                                  Raymond Hettinger
# 32                              Sarah Schattschneider
# 33                                     Yury Selivanov
# 34                                        Alark Joshi
# 35                                       Paul Everitt
# 36                                   Michael Sullivan
# 37                          Emily Morehouse-Valcarcel
# 38  Saishruthi Swaminathan\nGabriela de Queiroz\nK...
# 39                                      Adam Breindel
# 40                                       Paul Ganssle
# 41                                  Vanessa Barreiros
# 42                                        Vikram Bhat
# 43                                      Rachel Thomas
# 44                                         Annie Cook
# 45                                  R.Gabriel Esteves
# 46                                           Julia Ma
# 47                                       Łukasz Langa
# 48                                         David Lord
# 49                                    Keeley Takimoto
# 50                                 Antonio Piccolboni
# 51                                        Thor Whalen
# 52                                    Stefan Krawczyk
# 53                                     melissa fabros
# 54                                 Justina Petraityte
# 55                                    Mahmoud Hashemi
# 56                                    Luciano Ramalho
# 57                                     Raul Maldonado
#
#                      categories  \
# 0                          [ai]
# 1                      [python]
# 2                      [python]
# 3                 [devops, web]
# 4                          [ai]
# 5                 [python, web]
# 6                      [python]
# 7                 [python, web]
# 8   [ai, python, speed, devops]
# 9                          [ai]
# 10              [python, speed]
# 11             [devops, python]
# 12              [devops, speed]
# 13                     [python]
# 14             [devops, python]
# 15                 [ai, python]
# 16                  [community]
# 17                     [python]
# 18                     [devops]
# 19                         [ai]
# 20                  [community]
# 21                  [ai, speed]
# 22             [python, devops]
# 23                 [ai, python]
# 24              [python, speed]
# 25                         [ai]
# 26                [python, web]
# 27                     [devops]
# 28                           []
# 29                        [web]
# 30                 [ai, python]
# 31                     [python]
# 32                         [ai]
# 33                      [speed]
# 34                         [ai]
# 35                     [python]
# 36              [speed, devops]
# 37                  [community]
# 38                 [devops, ai]
# 39              [ai, community]
# 40                     [python]
# 41                [python, web]
# 42                     [devops]
# 43                         [ai]
# 44              [speed, python]
# 45                  [ai, speed]
# 46                     [python]
# 47                     [python]
# 48                [python, web]
# 49                         [ai]
# 50                     [python]
# 51                         [ai]
# 52      [devops, python, speed]
# 53                         [ai]
# 54                 [ai, python]
# 55      [devops, python, speed]
# 56                     [python]
# 57                         [ai]
#
#                                           description
# 0   Innovations in machine learning are changing o...
# 1   In 2017, CPython codebase was moved to GitHub ...
# 2   Curious what's coming next for Python? Well, P...
# 3   Without a unified analytics solution, it has b...
# 4   In this talk, we present Koalas, a new open so...
# 5   GraphQL has become the de facto successor to R...
# 6   Elected as prescribed in PEP 8016, the Python ...
# 7   Programming for the Web requires 5 languages a...
# 8   We will share our experiences on building Meta...
# 9   The talk provides an overview of the ad tech e...
# 10  SQL can seem like an obscure but somehow usefu...
# 11  At NerdWallet we are heavy Terraform users, bu...
# 12  Puzzling over performance problems in producti...
# 13  The strengths and weaknesses of Python lend th...
# 14  Dependency Injection is a basic technique in o...
# 15  Last couple of years have witnessed an immense...
# 16  Everyone deserves to make the most of their ca...
# 17  GDB is powerful, and can be extended with Pyth...
# 18  Most of us have installed a Python package, bu...
# 19  As the complexity and volume of data grows, da...
# 20  Too often, the people giving talks have alread...
# 21  It’s 2019, and Moore’s Law is dead. CPU perfor...
# 22  Have you ever wondered how Python debugging lo...
# 23  Challenges with Audio Classification problems ...
# 24  Learn how the open source Python module CuPy w...
# 25  Learn how to build a network web in Python to ...
# 26  Api's all have a defined structure, they somet...
# 27  Pytest is a widely-used, full-featured Python ...
# 28  Lightning talks are 5-minute talk slots with o...
# 29  An introduction to Python on hardware from the...
# 30  Together we live code (in a RISE slideshow) a ...
# 31  or "Strategies learned from coaching, teaching...
# 32  Heard of Apache Airflow? Do you work with Airf...
# 33  The talk will introduce people to EdgeDB and h...
# 34  I will present strategies to create effective ...
# 35  Make Sphinx your own, in 30 hilarious minutes....
# 36  Dropbox is a heavy user of the mypy type check...
# 37  Python Core Developers help shape and build th...
# 38  Seamlessly serve state-of-the-art deep learnin...
# 39  This talk is less about technical success and ...
# 40  This talk will arm you with some tools to desi...
# 41  In Django, we have a powerful tool called ORM ...
# 42  Unit testing is loved by so many that it is al...
# 43  Through a series of case studies, I will illus...
# 44  Asyncio is the latest and greatest way to writ...
# 45  The Python Machine Learning stack is notable f...
# 46  3D printers are becoming more and more accessi...
# 47  What good is a code style if it's not internal...
# 48  Browsers provide many ways to help keep your u...
# 49  As the demand grows for data science in indust...
# 50  APIs are important. It's how your packages rel...
# 51  In this talk I will present a project (coined ...
# 52  At Stitch Fix most application logs are output...
# 53  Kiva has provided an enormous amount of data t...
# 54  AI assistants are getting a great deal of atte...
# 55  If you had to build a software application rig...
# 56  Java is object oriented and Haskell is functio...
# 57  Python development has had a great emergence i...

# %%
talks_attended = {
    "As We May Program",
    "PEP 581 and PEP 588: Migrating CPython's Issue Tracker",
    "Koalas: Easy Transition from pandas to Apache Spark",
    "Pushing the limits of Python: ML infra at Netflix",
    "An Intro to Load Testing with Locust and Python",
    "Dependency Injection, Quickly",
    "Python and R for Advanced Analytics",
    "Understanding Python’s Debugging Internals",
    "How to Write Pytest Plugins",
    "(Deep) Learn You a Neural Net for Great Good!",
    "Effective Visual Representations using Python",
    "Deploy Deep Learning models as Microservices in minutes",
    "Patterns for Clean API Design",
    "Understanding Concurrency in Python!",
    "Writing good python APIs with autosig",
    "Why you should be using structured logs",
    "Ask the Ecosystem: Lessons from 200+ FOSS Applications",
}
df["attended"] = df["title"].apply(lambda t: t in talks_attended)
assert df["attended"].value_counts()[True] == len(talks_attended)  # Means a match was found for each title

# %%
# Save for when website eventually changes
import pickle
import os

if os.path.exists("pb_data.df"):
    print("Pickled dataframe already exists, skipping.")
else:
    print("Pickling data frame.")
    with open("pb_data.df", "wb") as f:
        pickle.dump(df, f)
# Out:
# Pickled dataframe already exists, skipping.

# %%
attendance_categories = collections.namedtuple("AttendanceCategories", ["count", "category", "disposition"])
data = list()

# flattened = [item for sublist in df["categories"] for item in sublist]
# total_count = collections.Counter(flattened)
# [data.append(attendance_categories(count, category, "total")) for category, count in total_count.items()]
my_flattened = [item for sublist in df[df["attended"] == True]["categories"] for item in sublist]
attended_count = collections.Counter(my_flattened)
[data.append(attendance_categories(count, category, "attended")) for category, count in attended_count.items()]
unattended_flattened = [item for sublist in df[df["attended"] == False]["categories"] for item in sublist]
unattended_count = collections.Counter(unattended_flattened)
[data.append(attendance_categories(count, category, "unattended")) for category, count in unattended_count.items()]

source = pd.DataFrame(data=data)

# %%
# https://github.com/ft-interactive/chart-doctor/tree/master/visual-vocabulary

import altair as alt
from vega_datasets import data

alt.Chart(source).mark_bar().encode(
    x='category',
    y='count',
    color='disposition',
    order=alt.Order('disposition', sort='descending'),
)
